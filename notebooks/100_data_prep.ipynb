# %%
import pandas as pd
bgn_yr = 2017
end_yr = 2018
html_path_template = "https://www.pro-football-reference.com/years/{}/passing.htm"
  
del spark_df_stack

for year in range(bgn_yr,end_yr+1):
  html_path = "https://www.pro-football-reference.com/years/{}/passing.htm".format(year)
  df = pd.read_html(html_path)[0]
  df = df.loc[(df["Tm"] != "Tm") & (df["Pos"] == "QB")]
  df = df.apply(pd.to_numeric, errors="ignore")
  
  spark_temp_df = spark.createDataFrame(df)
  
  try:
    spark_df_stack = spark_df_stack.union(spark_temp_df)
  except NameError:
    spark_df_stack = spark_temp_df
    
  del spark_temp_df
  
display(spark_df_stack)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
display(spark_df_stack)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
